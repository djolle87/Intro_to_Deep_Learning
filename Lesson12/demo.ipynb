# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import lstm, time
# Out:
# Using TensorFlow backend.

# %%
# Step 1 Load Data
X_train, y_train, X_test, y_test = lstm.load_data('data/sp500.csv', 50, True)

# %%
# Step 2 Build Model
model = Sequential()

model.add(LSTM(
    input_dim=1,
    output_dim=50,
    return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
    100,
    return_sequences=False))

model.add(Dropout(0.2))

model.add(Dense(output_dim=1))

model.add(Activation('linear'))

start = time.time()
model.compile(loss='mse', optimizer='rmsprop')
print('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.02201676368713379

# %%
# Step 3 Train the model
model.fit(
    X_train,
    y_train,
    batch_size=512,
    nb_epoch=1,
    validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/1
#  512/3523 [===>..........................] - ETA: 7s - loss: 0.0059
# 1024/3523 [=======>......................] - ETA: 3s - loss: 0.0049
# 1536/3523 [============>.................] - ETA: 2s - loss: 0.0044
# 2048/3523 [================>.............] - ETA: 1s - loss: 0.0038
# 2560/3523 [====================>.........] - ETA: 0s - loss: 0.0033
# 3072/3523 [=========================>....] - ETA: 0s - loss: 0.0031
# 3523/3523 [==============================] - 3s 885us/step - loss: 0.0030 - val_loss: 7.9396e-04

# %%
#Step 4 - Plot the predictions!
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
# Out:
# yo
